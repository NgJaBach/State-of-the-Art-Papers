# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\nhat minh\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai
import pandas as pd
import re
import numpy as np
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import os
from collections import defaultdict

# %%
df = pd.read_excel("datatouse.xlsx")

# %%
df
# Out:
#                                 subject            relation  \
# 0     acute_copd_exacerbation_infection  has_symptomatology
# 1     acute_copd_exacerbation_infection  has_symptomatology
# 2     acute_copd_exacerbation_infection       has_lifestyle
# 3     acute_copd_exacerbation_infection       has_anamnesis
# 4     acute_copd_exacerbation_infection         has_therapy
# ...                                 ...                 ...
# 1732                 pulmonary_embolism  has_symptomatology
# 1733                    localized_edema  has_symptomatology
# 1734                        sarcoidosis  has_symptomatology
# 1735                       panic_attack  has_symptomatology
# 1736           spontaneous_rib_fracture  has_symptomatology
#
#                                                  object
# 0     Worsening shortness of breath, chronic cough w...
# 1                 Increased sputum purulence and volume
# 2     Common in smokers or individuals exposed to po...
# 3     History of chronic obstructive pulmonary disea...
# 4     Bronchodilators and antibiotics if bacterial i...
# ...                                                 ...
# 1732  Does the pain radiate to another location?: si...
# 1733              Do you feel pain somewhere?: tibia(R)
# 1734             Do you feel pain somewhere?: breast(R)
# 1735  Do you feel pain somewhere?: side of the chest(R)
# 1736           Do you feel pain somewhere?: lower chest
#
# [1737 rows x 3 columns]

# %%
df.head()
# Out:
#                              subject            relation  \
# 0  acute_copd_exacerbation_infection  has_symptomatology
# 1  acute_copd_exacerbation_infection  has_symptomatology
# 2  acute_copd_exacerbation_infection       has_lifestyle
# 3  acute_copd_exacerbation_infection       has_anamnesis
# 4  acute_copd_exacerbation_infection         has_therapy
#
#                                               object
# 0  Worsening shortness of breath, chronic cough w...
# 1              Increased sputum purulence and volume
# 2  Common in smokers or individuals exposed to po...
# 3  History of chronic obstructive pulmonary disea...
# 4  Bronchodilators and antibiotics if bacterial i...

# %%
from dotenv import load_dotenv

nltk.download('punkt')
nltk.download('stopwords')

load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')

# Initialize the OpenAI client
client = openai.OpenAI(api_key=api_key)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Nhat
# [nltk_data]     Minh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Nhat
# [nltk_data]     Minh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
KG_file_path = 'datatouse.xlsx'
file_path = 'release_train_patients'

# %%
import os
import numpy as np

embedding_save_path = './Embeddings_saved/'

# Check if the directory exists, if not, create it
if not os.path.exists(embedding_save_path):
    os.makedirs(embedding_save_path)

# Define the file path for saving the embeddings
embeddings_path = os.path.join(embedding_save_path, 'KG_embeddings.npy')

# %%
def preprocess_text(text):
    try:
        if pd.isna(text):
            return ''
        text = re.sub(r'\(.*?\)', '', text).strip()
        text = text.replace('_', ' ')
        text = text.lower()
        text = text.translate(str.maketrans('', '', string.punctuation))
        tokens = word_tokenize(text)
        return ' '.join(tokens)
    except Exception as e:
        print(f"Error processing text: {text}. Error: {e}")
        return ''

# %%
kg_data = pd.read_excel(KG_file_path, usecols=['subject', 'relation', 'object'])

# %%
knowledge_graph = {}
for index, row in kg_data.iterrows():
    subject = row['subject']
    relation = row['relation']
    obj = row['object']

    if subject not in knowledge_graph:
        knowledge_graph[subject] = []
    knowledge_graph[subject].append((relation, obj))

    if obj not in knowledge_graph:
        knowledge_graph[obj] = []
    knowledge_graph[obj].append((relation, subject))

# %%
knowledge_graph.keys()
# Out:
# dict_keys(['acute_copd_exacerbation_infection', 'Worsening shortness of breath, chronic cough with sputum production', 'Increased sputum purulence and volume', 'Common in smokers or individuals exposed to pollutants', 'History of chronic obstructive pulmonary disease (COPD)', 'Bronchodilators and antibiotics if bacterial infection is present', 'bronchiectasis', 'Chronic productive cough with large amounts of purulent sputum', 'Frequent lung infections and shortness of breath', 'History of recurrent respiratory infections or cystic fibrosis', 'Chest physiotherapy to clear mucus, long-term antibiotics', 'More common in individuals with poor airway clearance mechanisms', 'bronchiolitis', 'Wheezing, difficulty breathing, and cyanosis, especially in children', 'History of recent viral respiratory infection, particularly RSV', 'Supportive care, bronchodilators, and oxygen in severe cases', 'More common in children exposed to second-hand smoke', 'bronchitis', 'Persistent cough, chest discomfort, and production of mucus', 'History of recent upper respiratory tract infection', 'Symptomatic treatment with cough suppressants and expectorants', 'Smoking is a major risk factor', 'bronchospasm_acute_asthma_exacerbation', 'Sudden onset of wheezing, shortness of breath, and chest tightness', 'History of asthma or atopy', 'Immediate use of bronchodilators (inhaled beta-agonists)', 'Triggered by allergens, cold air, or exercise', 'pulmonary_embolism', 'Sudden onset of pleuritic chest pain, shortness of breath, and hemoptysis', 'History of deep vein thrombosis (DVT) or recent surgery', 'Anticoagulation therapy (e.g., heparin)', 'Prolonged immobility or air travel increases risk', 'pulmonary_neoplasm', 'Persistent cough, hemoptysis, weight loss, and chest pain', 'History of smoking or occupational exposure to carcinogens', 'Chemotherapy, radiation, or surgical resection', 'Smoking and exposure to asbestos are major risk factors', 'spontaneous_pneumothorax', 'Sudden sharp chest pain and shortness of breath', 'History of chronic lung diseases such as COPD or cystic fibrosis', 'Needle aspiration or chest tube insertion to relieve lung pressure', 'urti', 'Sore throat, nasal congestion, and cough', 'History of frequent upper respiratory infections', 'Symptomatic treatment such as decongestants and analgesics', 'viral_pharyngitis', 'Sore throat, difficulty swallowing, and swollen lymph nodes', 'History of recent viral infection (e.g., common cold, influenza)', 'Supportive care, rest, and hydration', 'whooping_cough', 'Severe, hacking cough followed by a "whoop" sound during inspiration', 'Lack of vaccination or contact with infected individuals', 'Antibiotics (azithromycin) and supportive care', 'Highly contagious, especially in young children', 'acute_laryngitis', 'Hoarseness, loss of voice, and sore throat', 'Voice rest and symptomatic care', 'acute_pulmonary_edema', 'Sudden shortness of breath, wheezing, and frothy sputum', 'History of heart failure or fluid overload', 'Diuretics (e.g., furosemide) and oxygen therapy', 'croup', 'Barking cough, stridor, and hoarseness', 'Common in young children after a viral upper respiratory infection', 'Supportive care, corticosteroids, and humidified air', 'larygospasm', 'Sudden difficulty breathing and high-pitched wheezing (stridor)', 'History of GERD or recent upper respiratory tract infection', 'Airway management and antacids if GERD-related', 'epiglottitis', 'Severe sore throat, drooling, and difficulty swallowing', 'Lack of vaccination against Haemophilus influenzae type B (Hib)', 'Emergency airway management and antibiotics', 'pneumonia', 'Fever, productive cough, and pleuritic chest pain', 'Recent viral infection or immune suppression', 'Antibiotics for bacterial pneumonia, supportive care otherwise', 'atrial_fibrillation', 'Irregular heartbeat, palpitations, shortness of breath, and fatigue', 'History of hypertension, heart disease, or recent surgery', 'Anticoagulants to reduce stroke risk, beta-blockers ...

# %%
knowle
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 7
#       4 # Create a NetworkX graph from the knowledge_graph dictionary
#       5 G_visual = nx.Graph()
# ----> 7 for node, edges in knowledge_graph['object']:
#       8     for relation, neighbor in edges:
#       9         G_visual.add_edge(node, neighbor, relation=relation)
#
# KeyError: 'object'

# %%
print(kg_data.columns)
# Out:
# Index(['subject', 'relation', 'object'], dtype='object')

# %%
for index, row in kg_data.iterrows():
    print(f"Row {index}: Subject: {row['subject']}, Relation: {row['relation']}, Object: {row['object']}")
# Out:
# Row 0: Subject: acute_copd_exacerbation_infection, Relation: has_symptomatology, Object: Worsening shortness of breath, chronic cough with sputum production
# Row 1: Subject: acute_copd_exacerbation_infection, Relation: has_symptomatology, Object: Increased sputum purulence and volume
# Row 2: Subject: acute_copd_exacerbation_infection, Relation: has_lifestyle, Object: Common in smokers or individuals exposed to pollutants
# Row 3: Subject: acute_copd_exacerbation_infection, Relation: has_anamnesis, Object: History of chronic obstructive pulmonary disease (COPD)
# Row 4: Subject: acute_copd_exacerbation_infection, Relation: has_therapy, Object: Bronchodilators and antibiotics if bacterial infection is present
# Row 5: Subject: bronchiectasis, Relation: has_symptomatology, Object: Chronic productive cough with large amounts of purulent sputum
# Row 6: Subject: bronchiectasis, Relation: has_symptomatology, Object: Frequent lung infections and shortness of breath
# Row 7: Subject: bronchiectasis, Relation: has_anamnesis, Object: History of recurrent respiratory infections or cystic fibrosis
# Row 8: Subject: bronchiectasis, Relation: has_therapy, Object: Chest physiotherapy to clear mucus, long-term antibiotics
# Row 9: Subject: bronchiectasis, Relation: has_lifestyle, Object: More common in individuals with poor airway clearance mechanisms
# Row 10: Subject: bronchiolitis, Relation: has_symptomatology, Object: Wheezing, difficulty breathing, and cyanosis, especially in children
# Row 11: Subject: bronchiolitis, Relation: has_anamnesis, Object: History of recent viral respiratory infection, particularly RSV
# Row 12: Subject: bronchiolitis, Relation: has_therapy, Object: Supportive care, bronchodilators, and oxygen in severe cases
# Row 13: Subject: bronchiolitis, Relation: has_exposure, Object: More common in children exposed to second-hand smoke
# Row 14: Subject: bronchitis, Relation: has_symptomatology, Object: Persistent cough, chest discomfort, and production of mucus
# Row 15: Subject: bronchitis, Relation: has_anamnesis, Object: History of recent upper respiratory tract infection
# Row 16: Subject: bronchitis, Relation: has_therapy, Object: Symptomatic treatment with cough suppressants and expectorants
# Row 17: Subject: bronchitis, Relation: has_lifestyle, Object: Smoking is a major risk factor
# Row 18: Subject: bronchospasm_acute_asthma_exacerbation, Relation: has_symptomatology, Object: Sudden onset of wheezing, shortness of breath, and chest tightness
# Row 19: Subject: bronchospasm_acute_asthma_exacerbation, Relation: has_anamnesis, Object: History of asthma or atopy
# Row 20: Subject: bronchospasm_acute_asthma_exacerbation, Relation: has_therapy, Object: Immediate use of bronchodilators (inhaled beta-agonists)
# Row 21: Subject: bronchospasm_acute_asthma_exacerbation, Relation: has_exposure, Object: Triggered by allergens, cold air, or exercise
# Row 22: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Sudden onset of pleuritic chest pain, shortness of breath, and hemoptysis
# Row 23: Subject: pulmonary_embolism, Relation: has_anamnesis, Object: History of deep vein thrombosis (DVT) or recent surgery
# Row 24: Subject: pulmonary_embolism, Relation: has_therapy, Object: Anticoagulation therapy (e.g., heparin)
# Row 25: Subject: pulmonary_embolism, Relation: has_exposure, Object: Prolonged immobility or air travel increases risk
# Row 26: Subject: pulmonary_neoplasm, Relation: has_symptomatology, Object: Persistent cough, hemoptysis, weight loss, and chest pain
# Row 27: Subject: pulmonary_neoplasm, Relation: has_anamnesis, Object: History of smoking or occupational exposure to carcinogens
# Row 28: Subject: pulmonary_neoplasm, Relation: has_therapy, Object: Chemotherapy, radiation, or surgical resection
# Row 29: Subject: pulmonary_neoplasm, Relation: has_lifestyle, Object: Smoking and exposure to asbestos are major risk factors
# Row 30: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Sudden sharp chest pain and shortness of breath
# Row 31: Subject: spontaneous_pneumothorax, Relation: has_anamnesis, Object: History of chronic lung diseases such as COPD or cystic fibrosis
# Row 32: Subject: spontaneous_pneumothorax, Relation: has_therapy, Object: Needle aspiration or chest tube insertion to relieve lung pressure
# Row 33: Subject: urti, Relation: has_symptomatology, Object: Sore throat, nasal congestion, and cough
# Row 34: Subject: urti, Relation: has_anamnesis, Object: History of frequent upper respiratory infections
# Row 35: Subject: urti, Relation: has_therapy, Object: Symptomatic treatment such as decongestants and analgesics
# Row 36: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Sore throat, difficulty swallowing, and swollen lymph nodes
# Row 37: Subject: viral_pharyngitis, Relation: has_anamnesis, Object: History of recent viral infection (e.g., common cold, influenza)
# Row 38: Subject: viral_pharyngitis, Relation: has_therapy, Object: Supportive care, rest, and hydration
# Row 39: Subject: whooping_cough, Relation: has_symptomatology, Object: Severe, hacking cough followed by a "whoop" sound during inspiration
# Row 40: Subject: whooping_cough, Relation: has_anamnesis, Object: Lack of vaccination or contact with infected individuals
# Row 41: Subject: whooping_cough, Relation: has_therapy, Object: Antibiotics (azithromycin) and supportive care
# Row 42: Subject: whooping_cough, Relation: has_exposure, Object: Highly contagious, especially in young children
# Row 43: Subject: acute_laryngitis, Relation: has_symptomatology, Object: Hoarseness, loss of voice, and sore throat
# Row 44: Subject: acute_laryngitis, Relation: has_anamnesis, Object: History of recent upper respiratory tract infection
# Row 45: Subject: acute_laryngitis, Relation: has_therapy, Object: Voice rest and symptomatic care
# Row 46: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Sudden shortness of breath, wheezing, and frothy sputum
# Row 47: Subject: acute_pulmonary_edema, Relation: has_anamnesis, Object: History of heart failure or fluid overload
# Row 48: Subject: acute_pulmonary_edema, Relation: has_therapy, Object: Diuretics (e.g., furosemide) and oxygen therapy
# Row 49: Subject: croup, Relation: has_symptomatology, Object: Barking cough, stridor, and hoarseness
# Row 50: Subject: croup, Relation: has_anamnesis, Object: Common in young children after a viral upper respiratory infection
# Row 51: Subject: croup, Relation: has_therapy, Object: Supportive care, corticosteroids, and humidified air
# Row 52: Subject: larygospasm, Relation: has_symptomatology, Object: Sudden difficulty breathing and high-pitched wheezing (stridor)
# Row 53: Subject: larygospasm, Relation: has_anamnesis, Object: History of GERD or recent upper respiratory tract infection
# Row 54: Subject: larygospasm, Relation: has_therapy, Object: Airway management and antacids if GERD-related
# Row 55: Subject: epiglottitis, Relation: has_symptomatology, Object: Severe sore throat, drooling, and difficulty swallowing
# Row 56: Subject: epiglottitis, Relation: has_anamnesis, Object: Lack of vaccination against Haemophilus influenzae type B (Hib)
# Row 57: Subject: epiglottitis, Relation: has_therapy, Object: Emergency airway management and antibiotics
# Row 58: Subject: pneumonia, Relation: has_symptomatology, Object: Fever, productive cough, and pleuritic chest pain
# Row 59: Subject: pneumonia, Relation: has_anamnesis, Object: Recent viral infection or immune suppression
# Row 60: Subject: pneumonia, Relation: has_therapy, Object: Antibiotics for bacterial pneumonia, supportive care otherwise
# Row 61: Subject: atrial_fibrillation, Relation: has_symptomatology, Object: Irregular heartbeat, palpitations, shortness of breath, and fatigue
# Row 62: Subject: atrial_fibrillation, Relation: has_anamnesis, Object: History of hypertension, heart disease, or recent surgery
# Row 63: Subject: atrial_fibrillation, Relation: has_therapy, Object: Anticoagulants to reduce stroke risk, beta-blockers, or cardioversion
# Row 64: Subject: atrial_fibrillation, Relation: has_exposure, Object: Triggered by high alcohol intake, caffeine, or stress
# Row 65: Subject: myocarditis, Relation: has_symptomatology, Object: Chest pain, fatigue, shortness of breath, and signs of heart failure
# Row 66: Subject: myocarditis, Relation: has_anamnesis, Object: Recent viral infection (e.g., Coxsackie virus) or autoimmune disease
# Row 67: Subject: myocarditis, Relation: has_therapy, Object: Supportive care, corticosteroids in autoimmune cases
# Row 68: Subject: myocarditis, Relation: has_exposure, Object: Often linked to viral infections, especially respiratory viruses
# Row 69: Subject: pericarditis, Relation: has_symptomatology, Object: Sharp chest pain, often worsened by lying down, and relieved by sitting up
# Row 70: Subject: pericarditis, Relation: has_anamnesis, Object: History of viral infections or recent myocardial infarction
# Row 71: Subject: pericarditis, Relation: has_therapy, Object: NSAIDs or colchicine for inflammation, corticosteroids in severe cases
# Row 72: Subject: pericarditis, Relation: has_exposure, Object: Triggered by viral infections or post-heart attack inflammation
# Row 73: Subject: psvt, Relation: has_symptomatology, Object: Sudden onset of palpitations, dizziness, and chest discomfort
# Row 74: Subject: psvt, Relation: has_anamnesis, Object: Often no underlying heart disease, may occur in healthy individuals
# Row 75: Subject: psvt, Relation: has_therapy, Object: Vagal maneuvers, adenosine, or electrical cardioversion
# Row 76: Subject: psvt, Relation: has_exposure, Object: May be triggered by caffeine, stress, or alcohol
# Row 77: Subject: possible_nstemi_stemi, Relation: has_symptomatology, Object: Severe chest pain or discomfort radiating to the arm or jaw, sweating, and nausea
# Row 78: Subject: possible_nstemi_stemi, Relation: has_anamnesis, Object: History of coronary artery disease or previous heart attack
# Row 79: Subject: possible_nstemi_stemi, Relation: has_therapy, Object: Immediate administration of aspirin, nitroglycerin, and thrombolytics
# Row 80: Subject: possible_nstemi_stemi, Relation: has_exposure, Object: Triggered by physical exertion or emotional stress
# Row 81: Subject: stable_angina, Relation: has_symptomatology, Object: Chest discomfort or pain during physical exertion, relieved by rest
# Row 82: Subject: stable_angina, Relation: has_anamnesis, Object: History of coronary artery disease or atherosclerosis
# Row 83: Subject: stable_angina, Relation: has_therapy, Object: Nitrates, beta-blockers, and lifestyle changes
# Row 84: Subject: unstable_angina, Relation: has_symptomatology, Object: Chest pain that occurs at rest, not relieved by nitroglycerin
# Row 85: Subject: unstable_angina, Relation: has_anamnesis, Object: History of coronary artery disease, previous heart attack
# Row 86: Subject: unstable_angina, Relation: has_therapy, Object: Emergency medical intervention with antiplatelet therapy or surgery
# Row 87: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Sudden pleuritic chest pain, shortness of breath, and hemoptysis
# Row 88: Subject: pulmonary_embolism, Relation: has_therapy, Object: Anticoagulation therapy (e.g., heparin), thrombolytics in severe cases
# Row 89: Subject: pulmonary_embolism, Relation: has_exposure, Object: Triggered by prolonged immobility or air travel
# Row 90: Subject: myasthenia_gravis, Relation: has_symptomatology, Object: Muscle weakness that worsens with activity and improves with rest
# Row 91: Subject: myasthenia_gravis, Relation: has_symptomatology, Object: Ptosis (drooping eyelids) and double vision
# Row 92: Subject: myasthenia_gravis, Relation: has_anamnesis, Object: Autoimmune disorder targeting acetylcholine receptors
# Row 93: Subject: myasthenia_gravis, Relation: has_therapy, Object: Cholinesterase inhibitors and immunosuppressants
# Row 94: Subject: myasthenia_gravis, Relation: has_immunology, Object: Autoantibodies against acetylcholine receptors
# Row 95: Subject: guillain_barre_syndrome, Relation: has_symptomatology, Object: Progressive muscle weakness starting in the legs and ascending upwards
# Row 96: Subject: guillain_barre_syndrome, Relation: has_symptomatology, Object: Reduced reflexes and paralysis in severe cases
# Row 97: Subject: guillain_barre_syndrome, Relation: has_anamnesis, Object: Often triggered by a preceding viral infection or vaccination
# Row 98: Subject: guillain_barre_syndrome, Relation: has_therapy, Object: Intravenous immunoglobulin (IVIG) or plasma exchange
# Row 99: Subject: guillain_barre_syndrome, Relation: has_immunology, Object: Immune-mediated attack on the peripheral nervous system
# Row 100: Subject: cluster_headache, Relation: has_symptomatology, Object: Excruciating one-sided headache, often around the eye (cluster pattern)
# Row 101: Subject: cluster_headache, Relation: has_symptomatology, Object: Tearing, red eye, and nasal congestion during attacks
# Row 102: Subject: cluster_headache, Relation: has_anamnesis, Object: History of episodic or chronic severe headaches, often with remission
# Row 103: Subject: cluster_headache, Relation: has_therapy, Object: Oxygen therapy and triptans during attacks
# Row 104: Subject: cluster_headache, Relation: has_lifestyle, Object: More common in heavy smokers or individuals who consume alcohol
# Row 105: Subject: acute_dystonic_reactions, Relation: has_symptomatology, Object: Sudden, involuntary muscle contractions and twisting movements
# Row 106: Subject: acute_dystonic_reactions, Relation: has_anamnesis, Object: Often triggered by medications like antipsychotics or antiemetics
# Row 107: Subject: acute_dystonic_reactions, Relation: has_therapy, Object: Immediate administration of anticholinergic agents like benztropine
# Row 108: Subject: acute_dystonic_reactions, Relation: has_exposure, Object: Occurs after use of dopamine-blocking medications
# Row 109: Subject: sle, Relation: has_symptomatology, Object: Butterfly-shaped rash on the face, joint pain, and fatigue
# Row 110: Subject: sle, Relation: has_symptomatology, Object: Photosensitivity and ulcers in the mouth or nose
# Row 111: Subject: sle, Relation: has_anamnesis, Object: History of autoimmune conditions or family history of autoimmune diseases
# Row 112: Subject: sle, Relation: has_therapy, Object: Immunosuppressants such as corticosteroids, hydroxychloroquine
# Row 113: Subject: sle, Relation: has_immunology, Object: Autoantibodies like ANA (antinuclear antibodies)
# Row 114: Subject: sle, Relation: has_exposure, Object: Exposure to sunlight often worsens symptoms (photosensitivity)
# Row 115: Subject: sarcoidosis, Relation: has_symptomatology, Object: Granulomas in lungs or lymph nodes, leading to cough or chest pain
# Row 116: Subject: sarcoidosis, Relation: has_symptomatology, Object: Skin lesions, eye inflammation, and fever
# Row 117: Subject: sarcoidosis, Relation: has_anamnesis, Object: History of respiratory issues or skin rashes
# Row 118: Subject: sarcoidosis, Relation: has_therapy, Object: Corticosteroids or immunosuppressants for inflammation
# Row 119: Subject: sarcoidosis, Relation: has_immunology, Object: Immune-mediated formation of granulomas in organs
# Row 120: Subject: sarcoidosis, Relation: has_exposure, Object: May be linked to environmental triggers, such as dust or chemicals
# Row 121: Subject: anaphylaxis, Relation: has_symptomatology, Object: Sudden onset of difficulty breathing, swelling, and low blood pressure
# Row 122: Subject: anaphylaxis, Relation: has_anamnesis, Object: History of severe allergies, especially to foods, insect stings, or medications
# Row 123: Subject: anaphylaxis, Relation: has_therapy, Object: Immediate administration of epinephrine (adrenaline)
# Row 124: Subject: anaphylaxis, Relation: has_immunology, Object: IgE-mediated hypersensitivity reaction
# Row 125: Subject: allergic_sinusitis, Relation: has_symptomatology, Object: Nasal congestion, itchy eyes, sneezing, and runny nose
# Row 126: Subject: allergic_sinusitis, Relation: has_anamnesis, Object: History of seasonal allergies or exposure to common allergens
# Row 127: Subject: allergic_sinusitis, Relation: has_therapy, Object: Antihistamines and nasal corticosteroids for symptom management
# Row 128: Subject: allergic_sinusitis, Relation: has_immunology, Object: IgE-mediated allergic reaction to airborne allergens
# Row 129: Subject: allergic_sinusitis, Relation: has_exposure, Object: Exposure to pollen, dust, pet dander, or mold triggers symptoms
# Row 130: Subject: panic_attack, Relation: has_symptomatology, Object: Sudden onset of intense fear, palpitations, sweating, and shortness of breath
# Row 131: Subject: panic_attack, Relation: has_symptomatology, Object: Chest pain, dizziness, or a feeling of impending doom
# Row 132: Subject: panic_attack, Relation: has_anamnesis, Object: History of anxiety disorders or stressful life events
# Row 133: Subject: panic_attack, Relation: has_therapy, Object: Cognitive-behavioral therapy (CBT) and anti-anxiety medications (benzodiazepines)
# Row 134: Subject: panic_attack, Relation: has_psychopathology, Object: Hyperactivity of the autonomic nervous system, leading to exaggerated fear responses
# Row 135: Subject: panic_attack, Relation: has_lifestyle, Object: More common in individuals with chronic stress, lack of sleep, or substance abuse
# Row 136: Subject: panic_attack, Relation: has_exposure, Object: Triggers include high-stress situations, caffeine, or traumatic events
# Row 137: Subject: spontaneous_rib_fracture, Relation: has_symptomatology, Object: Sudden, sharp pain in the chest or back, worsened by movement or deep breathing
# Row 138: Subject: spontaneous_rib_fracture, Relation: has_anamnesis, Object: History of osteoporosis or prolonged corticosteroid use
# Row 139: Subject: spontaneous_rib_fracture, Relation: has_lifestyle, Object: More common in individuals with low bone density or high-impact activities
# Row 140: Subject: spontaneous_rib_fracture, Relation: has_therapy, Object: Pain management with analgesics and limiting physical activity
# Row 141: Subject: spontaneous_rib_fracture, Relation: has_exposure, Object: Trauma or high-impact injuries can trigger rib fractures
# Row 142: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Sudden onset of sharp chest pain and shortness of breath
# Row 143: Subject: spontaneous_pneumothorax, Relation: has_anamnesis, Object: History of chronic lung conditions such as emphysema or cystic fibrosis
# Row 144: Subject: spontaneous_pneumothorax, Relation: has_therapy, Object: Needle aspiration or chest tube insertion to relieve pressure on the lung
# Row 145: Subject: spontaneous_pneumothorax, Relation: has_lifestyle, Object: Common in tall, thin individuals or heavy smokers
# Row 146: Subject: spontaneous_pneumothorax, Relation: has_exposure, Object: May occur after a forceful cough or intense physical exertion
# Row 147: Subject: inguinal_hernia, Relation: has_symptomatology, Object: A noticeable bulge in the groin area, worsened by coughing or lifting heavy objects
# Row 148: Subject: inguinal_hernia, Relation: has_anamnesis, Object: Family history of hernias or previous episodes of abdominal wall weakness
# Row 149: Subject: inguinal_hernia, Relation: has_therapy, Object: Requires surgical repair to prevent complications such as bowel strangulation
# Row 150: Subject: inguinal_hernia, Relation: has_lifestyle, Object: Risk factors include heavy lifting and straining during physical activity
# Row 151: Subject: inguinal_hernia, Relation: has_exposure, Object: Often triggered by lifting heavy objects, which increases abdominal pressure
# Row 152: Subject: anemia, Relation: has_symptomatology, Object: Fatigue, pallor, and shortness of breath, especially after exertion
# Row 153: Subject: anemia, Relation: has_symptomatology, Object: Dizziness, headaches, and cold hands or feet
# Row 154: Subject: anemia, Relation: has_anamnesis, Object: History of chronic blood loss (e.g., heavy menstruation) or poor diet
# Row 155: Subject: anemia, Relation: has_therapy, Object: Iron supplements for iron-deficiency anemia, or blood transfusions in severe cases
# Row 156: Subject: anemia, Relation: has_lifestyle, Object: Risk factors include poor nutrition, particularly diets low in iron or vitamin B12
# Row 157: Subject: anemia, Relation: has_exposure, Object: Exposure to environmental toxins or certain medications may contribute to anemia
# Row 158: Subject: anemia, Relation: has_immunology, Object: Autoimmune hemolytic anemia involves the immune system attacking red blood cells
# Row 159: Subject: gerd, Relation: has_symptomatology, Object: Heartburn, acid regurgitation, and chest pain, especially after meals
# Row 160: Subject: gerd, Relation: has_anamnesis, Object: History of frequent indigestion, obesity, or hiatal hernia
# Row 161: Subject: gerd, Relation: has_therapy, Object: Proton pump inhibitors (PPIs) or lifestyle changes (diet modification)
# Row 162: Subject: gerd, Relation: has_exposure, Object: Triggered by fatty foods, caffeine, alcohol, or smoking
# Row 163: Subject: boerhaave_syndrome, Relation: has_symptomatology, Object: Severe chest pain, vomiting, and subcutaneous emphysema
# Row 164: Subject: boerhaave_syndrome, Relation: has_anamnesis, Object: History of forceful vomiting or retching, alcohol abuse
# Row 165: Subject: boerhaave_syndrome, Relation: has_therapy, Object: Emergency surgical repair and intravenous antibiotics
# Row 166: Subject: pancreatic_neoplasm, Relation: has_symptomatology, Object: Painless jaundice, weight loss, and dark urine
# Row 167: Subject: pancreatic_neoplasm, Relation: has_anamnesis, Object: History of chronic pancreatitis or diabetes
# Row 168: Subject: pancreatic_neoplasm, Relation: has_therapy, Object: Surgical resection, chemotherapy, or palliative care
# Row 169: Subject: pancreatic_neoplasm, Relation: has_lifestyle, Object: Smoking and alcohol abuse are significant risk factors
# Row 170: Subject: scombroid_food_poisoning, Relation: has_symptomatology, Object: Facial flushing, headache, and rapid pulse, occurring shortly after eating fish
# Row 171: Subject: scombroid_food_poisoning, Relation: has_anamnesis, Object: Recent consumption of improperly stored fish, particularly tuna
# Row 172: Subject: scombroid_food_poisoning, Relation: has_therapy, Object: Antihistamines and supportive care
# Row 173: Subject: inguinal_hernia, Relation: has_symptomatology, Object: Groin pain and a visible bulge, worsened by coughing or lifting
# Row 174: Subject: inguinal_hernia, Relation: has_anamnesis, Object: History of heavy lifting or chronic cough
# Row 175: Subject: inguinal_hernia, Relation: has_therapy, Object: Surgical repair (herniorrhaphy or hernioplasty)
# Row 176: Subject: inguinal_hernia, Relation: has_lifestyle, Object: Common in individuals involved in heavy manual labor
# Row 177: Subject: tuberculosis, Relation: has_symptomatology, Object: Persistent cough lasting more than 3 weeks, night sweats, weight loss
# Row 178: Subject: tuberculosis, Relation: has_anamnesis, Object: History of exposure to individuals with active TB, HIV-positive status
# Row 179: Subject: tuberculosis, Relation: has_therapy, Object: Long-term antibiotic treatment (isoniazid, rifampin)
# Row 180: Subject: tuberculosis, Relation: has_exposure, Object: Close contact in crowded conditions, weakened immune system
# Row 181: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Flu-like symptoms such as fever, sore throat, and lymphadenopathy
# Row 182: Subject: hiv_initial_infection, Relation: has_anamnesis, Object: History of unprotected sexual intercourse or intravenous drug use
# Row 183: Subject: hiv_initial_infection, Relation: has_therapy, Object: Antiretroviral therapy (ART) to suppress viral load
# Row 184: Subject: hiv_initial_infection, Relation: has_exposure, Object: Exposure through blood transfusion, unprotected sex, or contaminated needles
# Row 185: Subject: ebola, Relation: has_symptomatology, Object: Sudden onset of fever, severe headache, vomiting, and hemorrhaging
# Row 186: Subject: ebola, Relation: has_anamnesis, Object: Recent travel to Ebola-endemic areas or contact with infected individuals
# Row 187: Subject: ebola, Relation: has_therapy, Object: Supportive care, rehydration, and investigational treatments
# Row 188: Subject: ebola, Relation: has_exposure, Object: Contact with infected body fluids, handling animals or carcasses
# Row 189: Subject: influenza, Relation: has_symptomatology, Object: High fever, chills, muscle aches, sore throat, and dry cough
# Row 190: Subject: influenza, Relation: has_anamnesis, Object: Previous seasonal flu, more severe in elderly or immunocompromised individuals
# Row 191: Subject: influenza, Relation: has_therapy, Object: Antiviral medications (oseltamivir) and supportive care
# Row 192: Subject: influenza, Relation: has_exposure, Object: Close contact in crowded environments, lack of vaccination
# Row 193: Subject: chagas, Relation: has_symptomatology, Object: Fever, swelling near the site of infection (chagoma), and enlarged lymph nodes
# Row 194: Subject: chagas, Relation: has_anamnesis, Object: Travel to endemic regions in Latin America, exposure to triatomine bugs
# Row 195: Subject: chagas, Relation: has_therapy, Object: Antiparasitic medications (nifurtimox or benznidazole)
# Row 196: Subject: chagas, Relation: has_exposure, Object: Exposure to triatomine bugs (kissing bugs), poor housing conditions
# Row 197: Subject: acute_otitis_media, Relation: has_symptomatology, Object: Ear pain, hearing loss, and fever, often in young children
# Row 198: Subject: acute_otitis_media, Relation: has_anamnesis, Object: Recent upper respiratory infection or cold, frequent ear infections
# Row 199: Subject: acute_otitis_media, Relation: has_therapy, Object: Antibiotics (amoxicillin), pain relievers, and possible ear drainage
# Row 200: Subject: acute_otitis_media, Relation: has_exposure, Object: Common in children exposed to smoke or attending daycare
# Row 201: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Facial pain, nasal congestion, and purulent nasal discharge
# Row 202: Subject: acute_rhinosinusitis, Relation: has_anamnesis, Object: History of frequent colds or seasonal allergies
# Row 203: Subject: acute_rhinosinusitis, Relation: has_therapy, Object: Nasal decongestants, saline irrigation, and in some cases, antibiotics
# Row 204: Subject: acute_rhinosinusitis, Relation: has_exposure, Object: Exposure to allergens or viral infections
# Row 205: Subject: allergic_sinusitis, Relation: has_symptomatology, Object: Sneezing, nasal congestion, and watery eyes, often seasonal
# Row 206: Subject: allergic_sinusitis, Relation: has_anamnesis, Object: History of allergic rhinitis or hay fever
# Row 207: Subject: allergic_sinusitis, Relation: has_therapy, Object: Antihistamines, nasal corticosteroids, and allergen avoidance
# Row 208: Subject: allergic_sinusitis, Relation: has_exposure, Object: Exposure to pollen, dust mites, or mold
# Row 209: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Persistent nasal congestion, facial pain, and reduced sense of smell
# Row 210: Subject: chronic_rhinosinusitis, Relation: has_anamnesis, Object: History of repeated sinus infections or nasal polyps
# Row 211: Subject: chronic_rhinosinusitis, Relation: has_therapy, Object: Long-term nasal corticosteroids or surgery in severe cases
# Row 212: Subject: chronic_rhinosinusitis, Relation: has_exposure, Object: Exposure to allergens or irritants over prolonged periods
# Row 213: Subject: pneumonia, Relation: has_anamnesis, Object: History of viral infection or immune suppression
# Row 214: Subject: acute_copd_exacerbation_infection, Relation: is_a, Object: respiratory_system
# Row 215: Subject: bronchiectasis, Relation: is_a, Object: respiratory_system
# Row 216: Subject: bronchiolitis, Relation: is_a, Object: respiratory_system
# Row 217: Subject: bronchitis, Relation: is_a, Object: respiratory_system
# Row 218: Subject: pulmonary_neoplasm, Relation: is_a, Object: respiratory_system
# Row 219: Subject: atrial_fibrillation, Relation: is_a, Object: cardiovascular_system
# Row 220: Subject: myocarditis, Relation: is_a, Object: cardiovascular_system
# Row 221: Subject: pericarditis, Relation: is_a, Object: cardiovascular_system
# Row 222: Subject: psvt, Relation: is_a, Object: cardiovascular_system
# Row 223: Subject: gerd, Relation: is_a, Object: gastrointestinal_system
# Row 224: Subject: boerhaave_syndrome, Relation: is_a, Object: gastrointestinal_system
# Row 225: Subject: pancreatic_neoplasm, Relation: is_a, Object: gastrointestinal_system
# Row 226: Subject: tuberculosis, Relation: is_a, Object: infectious_diseases
# Row 227: Subject: hiv_initial_infection, Relation: is_a, Object: infectious_diseases
# Row 228: Subject: influenza, Relation: is_a, Object: infectious_diseases
# Row 229: Subject: myasthenia_gravis, Relation: is_a, Object: neurological_and_muscular_system
# Row 230: Subject: guillain_barre_syndrome, Relation: is_a, Object: neurological_and_muscular_system
# Row 231: Subject: sle, Relation: is_a, Object: autoimmune_and_immunological_diseases
# Row 232: Subject: sarcoidosis, Relation: is_a, Object: autoimmune_and_immunological_diseases
# Row 233: Subject: panic_attack, Relation: is_a, Object: psychiatric_and_stress_related_disorders
# Row 234: Subject: spontaneous_rib_fracture, Relation: is_a, Object: trauma_and_injury_related_conditions
# Row 235: Subject: anemia, Relation: is_a, Object: hematological_disorders
# Row 236: Subject: respiratory_system, Relation: is_a, Object: internal_medicine
# Row 237: Subject: cardiovascular_system, Relation: is_a, Object: internal_medicine
# Row 238: Subject: gastrointestinal_system, Relation: is_a, Object: internal_medicine
# Row 239: Subject: infectious_diseases, Relation: is_a, Object: internal_medicine
# Row 240: Subject: neurological_and_muscular_system, Relation: is_a, Object: internal_medicine
# Row 241: Subject: autoimmune_and_immunological_diseases, Relation: is_a, Object: internal_medicine
# Row 242: Subject: hematological_disorders, Relation: is_a, Object: internal_medicine
# Row 243: Subject: psychiatric_and_stress_related_disorders, Relation: is_a, Object: psychiatry
# Row 244: Subject: trauma_and_injury_related_conditions, Relation: is_a, Object: surgery
# Row 245: Subject: urti, Relation: has_symptomatology, Object: Do you have a fever (either felt or measured with a thermometer)?: TRUE
# Row 246: Subject: urti, Relation: has_symptomatology, Object: Do you feel pain somewhere?: temple(L)
# Row 247: Subject: urti, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 248: Subject: urti, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 249: Subject: urti, Relation: has_symptomatology, Object: Characterize your pain:: heavy
# Row 250: Subject: urti, Relation: has_symptomatology, Object: How fast did the pain appear?: 3
# Row 251: Subject: urti, Relation: has_symptomatology, Object: How intense is the pain?: 4
# Row 252: Subject: urti, Relation: has_symptomatology, Object: How precisely is the pain located?: 3
# Row 253: Subject: urti, Relation: has_lifestyle, Object: Do you live with 4 or more people?: TRUE
# Row 254: Subject: urti, Relation: has_lifestyle, Object: Do you smoke cigarettes?: TRUE
# Row 255: Subject: urti, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 256: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Do you have a fever (either felt or measured with a thermometer)?: TRUE
# Row 257: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Do you feel pain somewhere?: temple(L)
# Row 258: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 259: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 260: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Characterize your pain:: exhausting
# Row 261: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: How fast did the pain appear?: 2
# Row 262: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: How intense is the pain?: 7
# Row 263: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: How precisely is the pain located?: 7
# Row 264: Subject: hiv_initial_infection, Relation: has_anamnesis, Object: Have you had sexual intercourse with an HIV-positive partner in the past 12 months?: TRUE
# Row 265: Subject: hiv_initial_infection, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 266: Subject: pneumonia, Relation: has_symptomatology, Object: Do you feel pain somewhere?: posterior chest wall(L)
# Row 267: Subject: pneumonia, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 268: Subject: pneumonia, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 269: Subject: pneumonia, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 270: Subject: pneumonia, Relation: has_symptomatology, Object: How fast did the pain appear?: 6
# Row 271: Subject: pneumonia, Relation: has_symptomatology, Object: How intense is the pain?: 5
# Row 272: Subject: pneumonia, Relation: has_symptomatology, Object: How precisely is the pain located?: 2
# Row 273: Subject: pneumonia, Relation: has_symptomatology, Object: Do you have diffuse (widespread) muscle pain?: TRUE
# Row 274: Subject: pneumonia, Relation: has_lifestyle, Object: Do you smoke cigarettes?: TRUE
# Row 275: Subject: pneumonia, Relation: has_lifestyle, Object: Do you drink alcohol excessively or do you have an addiction to alcohol?: TRUE
# Row 276: Subject: pneumonia, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 277: Subject: urti, Relation: has_symptomatology, Object: How fast did the pain appear?: 4
# Row 278: Subject: urti, Relation: has_symptomatology, Object: How intense is the pain?: 7
# Row 279: Subject: urti, Relation: has_symptomatology, Object: How precisely is the pain located?: 5
# Row 280: Subject: urti, Relation: has_symptomatology, Object: How fast did the pain appear?: 2
# Row 281: Subject: urti, Relation: has_symptomatology, Object: How intense is the pain?: 5
# Row 282: Subject: urti, Relation: has_symptomatology, Object: How precisely is the pain located?: 4
# Row 283: Subject: urti, Relation: has_symptomatology, Object: Do you have diffuse (widespread) muscle pain?: TRUE
# Row 284: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: eye(R)
# Row 285: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 286: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: temple(L)
# Row 287: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 288: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How fast did the pain appear?: 1
# Row 289: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How intense is the pain?: 6
# Row 290: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 3
# Row 291: Subject: chronic_rhinosinusitis, Relation: has_lifestyle, Object: Do you smoke cigarettes?: TRUE
# Row 292: Subject: chronic_rhinosinusitis, Relation: has_immunology, Object: Are you more likely to develop common allergies than the general population?: TRUE
# Row 293: Subject: chronic_rhinosinusitis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 294: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Do you have a fever (either felt or measured with a thermometer)?: TRUE
# Row 295: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: pharynx
# Row 296: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 297: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 298: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Characterize your pain:: burning
# Row 299: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: How fast did the pain appear?: 3
# Row 300: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: How intense is the pain?: 5
# Row 301: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 9
# Row 302: Subject: viral_pharyngitis, Relation: has_lifestyle, Object: Do you smoke cigarettes?: TRUE
# Row 303: Subject: viral_pharyngitis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 304: Subject: viral_pharyngitis, Relation: has_exposure, Object: Have you been in contact with a person with similar symptoms in the past 2 weeks?: TRUE
# Row 305: Subject: anemia, Relation: has_symptomatology, Object: Do you feel pain somewhere?: temple(L)
# Row 306: Subject: anemia, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 307: Subject: anemia, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 308: Subject: anemia, Relation: has_symptomatology, Object: Characterize your pain:: a cramp
# Row 309: Subject: anemia, Relation: has_symptomatology, Object: How fast did the pain appear?: 4
# Row 310: Subject: anemia, Relation: has_symptomatology, Object: How intense is the pain?: 1
# Row 311: Subject: anemia, Relation: has_symptomatology, Object: How precisely is the pain located?: 3
# Row 312: Subject: anemia, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: Central America
# Row 313: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: temple(R)
# Row 314: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How fast did the pain appear?: 0
# Row 315: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How intense is the pain?: 2
# Row 316: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 8
# Row 317: Subject: atrial_fibrillation, Relation: has_therapy, Object: Do you have high blood pressure or do you take medications to treat high blood pressure?: TRUE
# Row 318: Subject: atrial_fibrillation, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 319: Subject: allergic_sinusitis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 320: Subject: larygospasm, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: North America
# Row 321: Subject: cluster_headache, Relation: has_symptomatology, Object: Do you feel pain somewhere?: temple(R)
# Row 322: Subject: cluster_headache, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 323: Subject: cluster_headache, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 324: Subject: cluster_headache, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 325: Subject: cluster_headache, Relation: has_symptomatology, Object: How fast did the pain appear?: 9
# Row 326: Subject: cluster_headache, Relation: has_symptomatology, Object: How intense is the pain?: 7
# Row 327: Subject: cluster_headache, Relation: has_symptomatology, Object: How precisely is the pain located?: 10
# Row 328: Subject: cluster_headache, Relation: has_lifestyle, Object: Do you drink alcohol excessively or do you have an addiction to alcohol?: TRUE
# Row 329: Subject: cluster_headache, Relation: has_anamnesis, Object: Have any of your family members been diagnosed with cluster headaches?: TRUE
# Row 330: Subject: cluster_headache, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 331: Subject: anaphylaxis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: epigastric
# Row 332: Subject: anaphylaxis, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 333: Subject: anaphylaxis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 334: Subject: anaphylaxis, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 335: Subject: anaphylaxis, Relation: has_symptomatology, Object: How fast did the pain appear?: 2
# Row 336: Subject: anaphylaxis, Relation: has_symptomatology, Object: How intense is the pain?: 3
# Row 337: Subject: anaphylaxis, Relation: has_symptomatology, Object: How precisely is the pain located?: 4
# Row 338: Subject: anaphylaxis, Relation: has_immunology, Object: Have you been in contact with or ate something that you have an allergy to?: TRUE
# Row 339: Subject: anaphylaxis, Relation: has_immunology, Object: Are you more likely to develop common allergies than the general population?: TRUE
# Row 340: Subject: anaphylaxis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 341: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: How fast did the pain appear?: 1
# Row 342: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 4
# Row 343: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Do you feel pain somewhere?: breast(L)
# Row 344: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 345: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 346: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Characterize your pain:: heartbreaking
# Row 347: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: How fast did the pain appear?: 8
# Row 348: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: How intense is the pain?: 8
# Row 349: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: How precisely is the pain located?: 1
# Row 350: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Do you have pain that is increased when you breathe in deeply?: TRUE
# Row 351: Subject: spontaneous_pneumothorax, Relation: has_lifestyle, Object: Do you smoke cigarettes?: TRUE
# Row 352: Subject: spontaneous_pneumothorax, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 353: Subject: cluster_headache, Relation: has_symptomatology, Object: How intense is the pain?: 9
# Row 354: Subject: cluster_headache, Relation: has_symptomatology, Object: How precisely is the pain located?: 5
# Row 355: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: posterior chest wall(L)
# Row 356: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 357: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Does the pain radiate to another location?: shoulder(L)
# Row 358: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Characterize your pain:: heavy
# Row 359: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: How fast did the pain appear?: 5
# Row 360: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: How intense is the pain?: 9
# Row 361: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: How precisely is the pain located?: 1
# Row 362: Subject: acute_pulmonary_edema, Relation: has_therapy, Object: Do you have high blood pressure or do you take medications to treat high blood pressure?: TRUE
# Row 363: Subject: acute_pulmonary_edema, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 364: Subject: tuberculosis, Relation: has_symptomatology, Object: Do you have a fever (either felt or measured with a thermometer)?: TRUE
# Row 365: Subject: tuberculosis, Relation: has_lifestyle, Object: Do you drink alcohol excessively or do you have an addiction to alcohol?: TRUE
# Row 366: Subject: tuberculosis, Relation: has_anamnesis, Object: Are you infected with the human immunodeficiency virus (HIV)?: TRUE
# Row 367: Subject: tuberculosis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 368: Subject: myasthenia_gravis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 369: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: iliac fossa(L)
# Row 370: Subject: panic_attack, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 371: Subject: panic_attack, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 372: Subject: panic_attack, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 373: Subject: panic_attack, Relation: has_symptomatology, Object: How fast did the pain appear?: 6
# Row 374: Subject: panic_attack, Relation: has_symptomatology, Object: How intense is the pain?: 8
# Row 375: Subject: panic_attack, Relation: has_symptomatology, Object: How precisely is the pain located?: 6
# Row 376: Subject: panic_attack, Relation: has_lifestyle, Object: Do you drink alcohol excessively or do you have an addiction to alcohol?: TRUE
# Row 377: Subject: panic_attack, Relation: has_psychopathology, Object: Do you feel anxious?: TRUE
# Row 378: Subject: panic_attack, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 379: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: pubis
# Row 380: Subject: panic_attack, Relation: has_symptomatology, Object: How fast did the pain appear?: 9
# Row 381: Subject: panic_attack, Relation: has_symptomatology, Object: How intense is the pain?: 7
# Row 382: Subject: panic_attack, Relation: has_symptomatology, Object: How precisely is the pain located?: 10
# Row 383: Subject: panic_attack, Relation: has_psychopathology, Object: Have you ever been diagnosed with depression?: TRUE
# Row 384: Subject: scombroid_food_poisoning, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 385: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you have a fever (either felt or measured with a thermometer)?: TRUE
# Row 386: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: pharynx
# Row 387: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you have pain somewhere, related to your reason for consulting?: TRUE
# Row 388: Subject: epiglottitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 389: Subject: epiglottitis, Relation: has_symptomatology, Object: Characterize your pain:: sharp
# Row 390: Subject: epiglottitis, Relation: has_symptomatology, Object: How fast did the pain appear?: 9
# Row 391: Subject: epiglottitis, Relation: has_symptomatology, Object: How intense is the pain?: 10
# Row 392: Subject: epiglottitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 10
# Row 393: Subject: epiglottitis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: N
# Row 394: Subject: urti, Relation: has_symptomatology, Object: Do you feel pain somewhere?: occiput
# ...
# Row 1598: Subject: cluster_headache, Relation: has_symptomatology, Object: Do you feel pain somewhere?: eye(R)
# Row 1599: Subject: sle, Relation: has_symptomatology, Object: Do you feel pain somewhere?: knee(L)
# Row 1600: Subject: inguinal_hernia, Relation: has_symptomatology, Object: Do you feel pain somewhere?: iliac fossa(R)
# Row 1601: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1602: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1603: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1604: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1605: Subject: myocarditis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: lower chest
# Row 1606: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Does the pain radiate to another location?: scapula(R)
# Row 1607: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: calf(R)
# Row 1608: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(L)
# Row 1609: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the neck(L)
# Row 1610: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: little toe (4)(L)
# Row 1611: Subject: anaphylaxis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1612: Subject: anaphylaxis, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1613: Subject: anaphylaxis, Relation: has_symptomatology, Object: How fast did the pain appear?: 0
# Row 1614: Subject: anaphylaxis, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1615: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Does the pain radiate to another location?: chin
# Row 1616: Subject: myocarditis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1617: Subject: myocarditis, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1618: Subject: myocarditis, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1619: Subject: myocarditis, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1620: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: thigh(R)
# Row 1621: Subject: acute_laryngitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tonsil(R)
# Row 1622: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: posterior chest wall(L)
# Row 1623: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Does the pain radiate to another location?: scapula(L)
# Row 1624: Subject: hiv_initial_infection, Relation: has_symptomatology, Object: Do you feel pain somewhere?: back of head
# Row 1625: Subject: bronchiolitis, Relation: has_lifestyle, Object: Do you live with 4 or more people?: TRUE
# Row 1626: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: trachea
# Row 1627: Subject: chagas, Relation: has_symptomatology, Object: Characterize your pain:: sensitive
# Row 1628: Subject: viral_pharyngitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tonsil(L)
# Row 1629: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: mouth
# Row 1630: Subject: boerhaave, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(L)
# Row 1631: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: toe (3)(L)
# Row 1632: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(L)
# Row 1633: Subject: acute_otitis_media, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1634: Subject: acute_otitis_media, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1635: Subject: acute_otitis_media, Relation: has_symptomatology, Object: How fast did the pain appear?: 0
# Row 1636: Subject: acute_otitis_media, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1637: Subject: acute_otitis_media, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1638: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: triceps(L)
# Row 1639: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(L)
# Row 1640: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: cheek(R)
# Row 1641: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(L)
# Row 1642: Subject: spontaneous_pneumothorax, Relation: has_symptomatology, Object: Do you feel pain somewhere?: lower chest
# Row 1643: Subject: bronchitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: lower chest
# Row 1644: Subject: sle, Relation: has_symptomatology, Object: Do you feel pain somewhere?: hip(L)
# Row 1645: Subject: stable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(R)
# Row 1646: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the neck(R)
# Row 1647: Subject: stable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: thyroid cartilage
# Row 1648: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: under the jaw
# Row 1649: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Does the pain radiate to another location?: thoracic spine
# Row 1650: Subject: boerhaave, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(R)
# Row 1651: Subject: chagas, Relation: has_symptomatology, Object: Characterize your pain:: tedious
# Row 1652: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(R)
# Row 1653: Subject: anaphylaxis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(R)
# Row 1654: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: trachea
# Row 1655: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(L)
# Row 1656: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: triceps(L)
# Row 1657: Subject: chagas, Relation: has_symptomatology, Object: Do you feel pain somewhere?: hypochondrium(R)
# Row 1658: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: forehead
# Row 1659: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: toe (3)(R)
# Row 1660: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(L)
# Row 1661: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: little toe (4)(R)
# Row 1662: Subject: chagas, Relation: has_symptomatology, Object: Do you feel pain somewhere?: pubis
# Row 1663: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: posterior chest wall(R)
# Row 1664: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(R)
# Row 1665: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(L)
# Row 1666: Subject: boerhaave, Relation: has_symptomatology, Object: Characterize your pain:: haunting
# Row 1667: Subject: spontaneous_rib_fracture, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1668: Subject: chagas, Relation: has_symptomatology, Object: Do you feel pain somewhere?: hypochondrium(L)
# Row 1669: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(L)
# Row 1670: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1671: Subject: gerd, Relation: has_symptomatology, Object: Characterize your pain:: haunting
# Row 1672: Subject: sle, Relation: has_symptomatology, Object: Do you feel pain somewhere?: hip(R)
# Row 1673: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(R)
# Row 1674: Subject: sarcoidosis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: thumb(L)
# Row 1675: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: triceps(L)
# Row 1676: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1677: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: cheek(L)
# Row 1678: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: scapula(R)
# Row 1679: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: triceps(R)
# Row 1680: Subject: acute_laryngitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1681: Subject: acute_laryngitis, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1682: Subject: acute_laryngitis, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1683: Subject: acute_laryngitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1684: Subject: sle, Relation: has_symptomatology, Object: Do you feel pain somewhere?: dorsal aspect of the wrist(R)
# Row 1685: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 1686: Subject: unstable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: thyroid cartilage
# Row 1687: Subject: chagas, Relation: has_symptomatology, Object: Do you feel pain somewhere?: iliac fossa(L)
# Row 1688: Subject: chagas, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(R)
# Row 1689: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: nowhere
# Row 1690: Subject: acute_rhinosinusitis, Relation: has_symptomatology, Object: Does the pain radiate to another location?: back of head
# Row 1691: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(L)
# Row 1692: Subject: inguinal_hernia, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1693: Subject: inguinal_hernia, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1694: Subject: inguinal_hernia, Relation: has_symptomatology, Object: How fast did the pain appear?: 0
# Row 1695: Subject: inguinal_hernia, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1696: Subject: stable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: thoracic spine
# Row 1697: Subject: sarcoidosis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: thumb(R)
# Row 1698: Subject: boerhaave, Relation: has_symptomatology, Object: Do you feel pain somewhere?: lower chest
# Row 1699: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: ankle(L)
# Row 1700: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1701: Subject: cluster_headache, Relation: has_symptomatology, Object: Do you feel pain somewhere?: forehead
# Row 1702: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: thoracic spine
# Row 1703: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tonsil(R)
# Row 1704: Subject: influenza, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the neck(R)
# Row 1705: Subject: stable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(L)
# Row 1706: Subject: influenza, Relation: has_symptomatology, Object: Do you feel pain somewhere?: back of the neck
# Row 1707: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Do you feel pain somewhere?: calf(L)
# Row 1708: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(L)
# Row 1709: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tibia(L)
# Row 1710: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tonsil(L)
# Row 1711: Subject: sarcoidosis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: hip(L)
# Row 1712: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Do you feel pain somewhere?: calf(R)
# Row 1713: Subject: sarcoidosis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: breast(L)
# Row 1714: Subject: boerhaave, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1715: Subject: boerhaave, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1716: Subject: boerhaave, Relation: has_symptomatology, Object: How fast did the pain appear?: 0
# Row 1717: Subject: boerhaave, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1718: Subject: boerhaave, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1719: Subject: unstable_angina, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(L)
# Row 1720: Subject: unstable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: biceps(R)
# Row 1721: Subject: acute_pulmonary_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1722: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: nowhere
# Row 1723: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: Characterize your pain:: NA
# Row 1724: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How intense is the pain?: 0
# Row 1725: Subject: chronic_rhinosinusitis, Relation: has_symptomatology, Object: How precisely is the pain located?: 0
# Row 1726: Subject: epiglottitis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: back of the neck
# Row 1727: Subject: bronchiolitis, Relation: has_exposure, Object: Have you traveled out of the country in the last 4 weeks?: North America
# Row 1728: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: flank(R)
# Row 1729: Subject: stable_angina, Relation: has_symptomatology, Object: Do you feel pain somewhere?: biceps(L)
# Row 1730: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Does the pain radiate to another location?: biceps(L)
# Row 1731: Subject: possible_nstemi__stemi, Relation: has_symptomatology, Object: Do you feel pain somewhere?: thoracic spine
# Row 1732: Subject: pulmonary_embolism, Relation: has_symptomatology, Object: Does the pain radiate to another location?: side of the chest(L)
# Row 1733: Subject: localized_edema, Relation: has_symptomatology, Object: Do you feel pain somewhere?: tibia(R)
# Row 1734: Subject: sarcoidosis, Relation: has_symptomatology, Object: Do you feel pain somewhere?: breast(R)
# Row 1735: Subject: panic_attack, Relation: has_symptomatology, Object: Do you feel pain somewhere?: side of the chest(R)
# Row 1736: Subject: spontaneous_rib_fracture, Relation: has_symptomatology, Object: Do you feel pain somewhere?: lower chest

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Nhat
# [nltk_data]     Minh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
kg_data['object_preprocessed'] = kg_data.apply(
    lambda row: preprocess_text(row['object']) if row['relation'] != 'is_a' else None,
    axis=1
)
symptom_nodes = list(kg_data['object_preprocessed'].dropna().unique())

# %%
def get_symptom_embeddings(symptom_nodes, save_path):
    embeddings_path = os.path.join(save_path, 'KG_embeddings.npy')
    if os.path.exists(embeddings_path):
        print("load existing embeddings...")
        return np.load(embeddings_path)
    else:
        print("generate new embeddings...")
        symptom_embeddings = []
        for symptom in tqdm(symptom_nodes):
            response = client.embeddings.create(
                input=symptom,
                model="text-embedding-3-large"
            )
            symptom_embeddings.append(response.data[0].embedding)
        np.save(embeddings_path, symptom_embeddings)

        return np.array(symptom_embeddings)


symptom_embeddings = get_symptom_embeddings(symptom_nodes, embedding_save_path)
# Out:
# load existing embeddings...

# %%
def find_top_n_similar_symptoms(query, symptom_nodes, symptom_embeddings, n):
    if pd.isna(query) or not query:
        return []
    query_preprocessed = preprocess_text(query)
    response = client.embeddings.create(
        input=query_preprocessed,
        model="text-embedding-3-large"
    )
    query_embedding = response.data[0].embedding
    if not query_embedding:
        return []

    if len(symptom_embeddings) > len(symptom_nodes):
        symptom_embeddings = symptom_embeddings[:len(symptom_nodes)]

    similarities = cosine_similarity([query_embedding], symptom_embeddings).flatten()

    top_n_symptoms = []
    unique_symptoms = set()
    top_n_indices = similarities.argsort()[::-1]

    for i in top_n_indices:
        if similarities[i] > 0.5 and symptom_nodes[i] not in unique_symptoms:
            top_n_symptoms.append(symptom_nodes[i])
            unique_symptoms.add(symptom_nodes[i])
        if len(top_n_symptoms) == n:
            break

    return top_n_symptoms

# %%
def compute_shortest_path_length(node1, node2, G):
    try:
        return nx.shortest_path_length(G, source=node1, target=node2)
    except nx.NetworkXNoPath:
        return float('inf')

categories = [
    "thoracoabdominal_pain_syndromes",
    "neuropathic_pain_syndromes",
    "craniofacial_pain_syndromes",
    "cervical_spine_pain_syndromes",
    "limb_and_joint_pain_syndromes",
    "back_pain_syndromes",
    "lumbar_degenerative_and_stenosis_and_radicular_and_sciatic_syndromes",
    "generalized_pain_syndromes",

]
G = nx.Graph()
for node, edges in knowledge_graph.items():
    for relation, neighbor in edges:
        G.add_edge(node, neighbor, relation=relation)

# %%
def get_diagnoses_for_symptom(symptom):

    diagnoses = []
    if symptom in G:
        for neighbor in G.neighbors(symptom):
            edge_data = G.get_edge_data(neighbor, symptom)
            if edge_data and 'relation' in edge_data and edge_data['relation'] != 'is_a':
                diagnoses.append(neighbor)
    return diagnoses

# %%
def find_closest_category(top_symptoms, categories,top_n):
    if isinstance(top_symptoms, pd.Series) and top_symptoms.empty:
        print("Warning: top_symptoms is empty.")
        return None
    category_votes = {category: 0 for category in categories}
    for symptom in top_symptoms:
        top_symptoms = list(set(top_symptoms))

        # print('symptom: ',symptom)
        if symptom not in G:
            print(f"Symptom node not found in graph: {symptom}")
            continue

        diagnosis_nodes = get_diagnoses_for_symptom(symptom)
        for diagnosis in diagnosis_nodes:

            individual_diagnoses = diagnosis.split(',')

            for single_diagnosis in individual_diagnoses:
                single_diagnosis = single_diagnosis.strip().replace(' ', '_').lower()  # 去掉前后空格
                if single_diagnosis not in G:
                    print(f"Diagnosis node not found in graph: {single_diagnosis}")
                    continue

                min_distance = float('inf')
                closest_category = None

                for category in categories:
                    if category not in G:
                        print(f"Category node not found in graph: {category}")
                        continue

                    try:
                        distance = nx.shortest_path_length(G, source=single_diagnosis, target=category)
                    except nx.NetworkXNoPath:
                        distance = float('inf')

                    if distance < min_distance:
                        min_distance = distance
                        closest_category = category

                if closest_category:
                    category_votes[closest_category] += 1
    print("Category votes:", category_votes)

    sorted_categories = sorted(category_votes.items(), key=lambda x: x[1], reverse=True)
    top_n_categories = [sorted_categories[i][0] for i in range(top_n)]
    return top_n_categories

# %%
def get_keyinfo_for_category(category, knowledge_graph):
    keyinfo_values = []
    for node, edges in knowledge_graph.items():
        if node == category:
            for relation, neighbor in edges:
                if relation == "is_a" and neighbor in knowledge_graph:
                    for rel, obj in knowledge_graph[neighbor]:
                        if rel == "has_keyinfo":
                            keyinfo_values.append(obj)
    return keyinfo_values

# %%
def get_subjects_for_objects(objects, knowledge_graph):
    subjects = []
    processed_objects = [obj.replace(' ', '_') for obj in objects]
    for obj in processed_objects:
        for index, row in knowledge_graph.iterrows():
            if row['object'] == obj:
                subjects.append(row['subject'])
    return subjects

# %%
def find_level3_for_symptoms(top_symptoms, knowledge_graph):
    level3_connections = {}
    for symptom in top_symptoms:
        subjects = get_subjects_for_objects([symptom], knowledge_graph)
        for subject in subjects:
            if subject in level3_connections:
                level3_connections[subject] += 1
            else:
                level3_connections[subject] = 1
    return level3_connections

# %%
def print_symptom_and_disease(symptom_nodes):
    for symptom in symptom_nodes:
        subjects = get_subjects_for_objects([symptom], kg_data)

# %%
def main_get_category_and_level3(n, participant_no,top_n):
    data = pd.read_csv(file_path, encoding='ISO-8859-1')

    row = data.loc[data['Participant No.'] == str(participant_no)]
    if row.empty:
        print(f"Participant No. {participant_no} not found!")
        return None

    tr = row["Level 2"].values[0]
    tr=tr.split(",")[0]

    level3real = row["Processed Diagnosis"].values[0]

    pain_location = row["Pain Presentation and Description"].values[0]
    pain_symptoms = row["Pain descriptions and assorted symptoms (self-report)"].values[0]
    pain_restriction = row["Pain restriction"].values[0]
    print(f'pain_location: {pain_location}')
    print(f'pain_symptoms: {pain_symptoms}')
    print(f'pain_restrction: {pain_restriction}')
    if pd.isna(pain_location):
        pain_location = ''
    if pd.isna(pain_symptoms):
        pain_symptoms = ''
    if pd.isna(pain_restriction):
        pain_symptoms = ''

# %%
def run_system():
    # Step 1: Set the parameters
    n = 5  # Number of top symptoms you want to retrieve
    participant_no = 12345  # Example participant number, replace with an actual number
    top_n = 3  # Number of top categories to return
    
    # Step 2: Ensure that the embeddings are loaded or generated
    print("Loading embeddings or generating new ones...")
    symptom_embeddings = get_symptom_embeddings(symptom_nodes, embedding_save_path)
    
    # Step 3: Get the most similar categories based on the participant's symptoms
    print(f"Getting categories and level 3 information for participant {participant_no}...")
    most_similar_category = main_get_category_and_level3(n, participant_no, top_n)
    
    if most_similar_category is not None:
        print(f"Most similar categories for participant {participant_no}: {most_similar_category}")
    else:
        print(f"No similar categories found for participant {participant_no}.")

# Run the system
run_system()
# Out:
# Loading embeddings or generating new ones...
# load existing embeddings...
# Getting categories and level 3 information for participant 12345...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Nhat Minh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Participant No.'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 21
#      18         print(f"No similar categories found for participant {participant_no}.")
#      20 # Run the system
# ---> 21 run_system()
#
# Cell In[53], line 13, in run_system()
#      11 # Step 3: Get the most similar categories based on the participant's symptoms
#      12 print(f"Getting categories and level 3 information for participant {participant_no}...")
# ---> 13 most_similar_category = main_get_category_and_level3(n, participant_no, top_n)
#      15 if most_similar_category is not None:
#      16     print(f"Most similar categories for participant {participant_no}: {most_similar_category}")
#
# Cell In[51], line 4, in main_get_category_and_level3(n, participant_no, top_n)
#       1 def main_get_category_and_level3(n, participant_no,top_n):
#       2     data = pd.read_csv(file_path, encoding='ISO-8859-1')
# ----> 4     row = data.loc[data['Participant No.'] == str(participant_no)]
#       5     if row.empty:
#       6         print(f"Participant No. {participant_no} not found!")
#
# File c:\Users\Nhat Minh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Nhat Minh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Participant No.'

# %%
def process_symptom_field(field_value, symptom_nodes, symptom_embeddings, n):
        if pd.isna(field_value) or field_value == '':
            return []
        return find_top_n_similar_symptoms(field_value, symptom_nodes, symptom_embeddings, n)

# %%
top_5_location_nodes = process_symptom_field(pain_location, symptom_nodes, symptom_embeddings, n)
top_5_symptom_nodes = process_symptom_field(pain_symptoms, symptom_nodes, symptom_embeddings, n)
top_5_painrestriction_nodes = process_symptom_field(pain_restriction, symptom_nodes, symptom_embeddings, n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 top_5_location_nodes = process_symptom_field(pain_location, symptom_nodes, symptom_embeddings, n)
#       2 top_5_symptom_nodes = process_symptom_field(pain_symptoms, symptom_nodes, symptom_embeddings, n)
#       3 top_5_painrestriction_nodes = process_symptom_field(pain_restriction, symptom_nodes, symptom_embeddings, n)
#
# NameError: name 'pain_location' is not defined

# %%
    top_5_location_nodes_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_location_nodes), 'object'].drop_duplicates()
    top_5_symptom_nodes_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_symptom_nodes), 'object'].drop_duplicates()
    top_5_painrestriction_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_painrestriction_nodes), 'object'].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 top_5_location_nodes_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_location_nodes), 'object'].drop_duplicates()
#       2 top_5_symptom_nodes_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_symptom_nodes), 'object'].drop_duplicates()
#       3 top_5_painrestriction_original = kg_data.loc[kg_data['object_preprocessed'].isin(top_5_painrestriction_nodes), 'object'].drop_duplicates()
#
# NameError: name 'top_5_location_nodes' is not defined

# %%
most_similar_category = find_closest_category(
        list(top_5_location_nodes_original) + list(top_5_symptom_nodes_original)+ list(top_5_painrestriction_original),
        categories,
        top_n
    )
    return most_similar_category
